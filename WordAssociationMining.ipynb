# %%
# !pip install -U scipy==1.10.0 numpy==1.23.5
# Out:
# Collecting scipy==1.10.0
#   Downloading scipy-1.10.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (34.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 42.1 MB/s eta 0:00:00
# Requirement already satisfied: numpy==1.23.5 in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.3
#     Uninstalling scipy-1.11.3:
#       Successfully uninstalled scipy-1.11.3
# Successfully installed scipy-1.10.0

# %%
# !pip install -U git+https://github.com/stephenhky/PyShortTextCategorization
# Out:
# Collecting git+https://github.com/stephenhky/PyShortTextCategorization
#   Cloning https://github.com/stephenhky/PyShortTextCategorization to /tmp/pip-req-build-qsylhi2x
#   Running command git clone --filter=blob:none --quiet https://github.com/stephenhky/PyShortTextCategorization /tmp/pip-req-build-qsylhi2x
#   Resolved https://github.com/stephenhky/PyShortTextCategorization to commit 71706fe6b33f0983d21c95b8339c8ca754ca8aca
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Cython>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (3.0.2)
# Requirement already satisfied: numpy>=1.23.3 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (1.23.5)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (1.10.0)
# Requirement already satisfied: joblib>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (1.3.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (1.2.2)
# Requirement already satisfied: tensorflow>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (2.13.0)
# Requirement already satisfied: keras>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (2.13.1)
# Requirement already satisfied: gensim>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (4.3.2)
# Requirement already satisfied: pandas>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (1.5.3)
# Requirement already satisfied: snowballstemmer>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (2.2.0)
# Collecting transformers>=4.32.0 (from shorttext==1.6.0)
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 16.1 MB/s eta 0:00:00
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from shorttext==1.6.0) (2.0.1+cu118)
# Collecting python-Levenshtein>=0.21.0 (from shorttext==1.6.0)
#   Downloading python_Levenshtein-0.22.0-py3-none-any.whl (9.4 kB)
# Collecting numba>=0.57.0 (from shorttext==1.6.0)
#   Downloading numba-0.58.0-cp310-cp310-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 35.8 MB/s eta 0:00:00
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim>=4.0.0->shorttext==1.6.0) (6.4.0)
# Collecting llvmlite<0.42,>=0.41.0dev0 (from numba>=0.57.0->shorttext==1.6.0)
#   Downloading llvmlite-0.41.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 MB 11.3 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->shorttext==1.6.0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.2.0->shorttext==1.6.0) (2023.3.post1)
# Collecting Levenshtein==0.22.0 (from python-Levenshtein>=0.21.0->shorttext==1.6.0)
#   Downloading Levenshtein-0.22.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (172 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.9/172.9 kB 11.8 MB/s eta 0:00:00
# Collecting rapidfuzz<4.0.0,>=2.3.0 (from Levenshtein==0.22.0->python-Levenshtein>=0.21.0->shorttext==1.6.0)
#   Downloading rapidfuzz-3.3.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 76.1 MB/s eta 0:00:00
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.2.0->shorttext==1.6.0) (3.2.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.1.21 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (23.5.26)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (1.59.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (3.9.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (16.0.6)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (3.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (3.20.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (67.7.2)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (1.16.0)
# Requirement already satisfied: tensorboard<2.14,>=2.13 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (2.13.0)
# Requirement already satisfied: tensorflow-estimator<2.14,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (2.13.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (2.3.0)
# Requirement already satisfied: typing-extensions<4.6.0,>=3.6.6 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (4.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (1.15.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.10/dist-packages (from tensorflow>=2.13.0->shorttext==1.6.0) (0.34.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->shorttext==1.6.0) (3.12.4)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->shorttext==1.6.0) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->shorttext==1.6.0) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->shorttext==1.6.0) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=2.0.0->shorttext==1.6.0) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->shorttext==1.6.0) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=2.0.0->shorttext==1.6.0) (17.0.2)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.32.0->shorttext==1.6.0)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 25.2 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.32.0->shorttext==1.6.0) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.32.0->shorttext==1.6.0) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.32.0->shorttext==1.6.0) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.32.0->shorttext==1.6.0)
#   Downloading tokenizers-0.14.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 67.0 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.32.0->shorttext==1.6.0)
#   Downloading safetensors-0.3.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 56.8 MB/s eta 0:00:00
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.32.0->shorttext==1.6.0) (4.66.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from astunparse>=1.6.0->tensorflow>=2.13.0->shorttext==1.6.0) (0.41.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers>=4.32.0->shorttext==1.6.0) (2023.6.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (3.4.4)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (3.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.32.0->shorttext==1.6.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.32.0->shorttext==1.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.32.0->shorttext==1.6.0) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.32.0->shorttext==1.6.0) (2023.7.22)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.32.0->shorttext==1.6.0)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 20.8 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=2.0.0->shorttext==1.6.0) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=2.0.0->shorttext==1.6.0) (1.3.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (1.3.1)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.14,>=2.13->tensorflow>=2.13.0->shorttext==1.6.0) (3.2.2)
# Building wheels for collected packages: shorttext
#   Building wheel for shorttext (pyproject.toml) ... done
#   Created wheel for shorttext: filename=shorttext-1.6.0-cp310-cp310-linux_x86_64.whl size=724495 sha256=234b37412b25f54157441c7995b72665475eae69f96dd21f704895bcdff4e8bd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-fi_mqcm1/wheels/84/07/3e/bb56d79459e5c3c9111c649d174481179ef9258e9559bdd72c
# Successfully built shorttext
# Installing collected packages: safetensors, rapidfuzz, llvmlite, numba, Levenshtein, huggingface-hub, tokenizers, python-Levenshtein, transformers, shorttext
#   Attempting uninstall: llvmlite
#     Found existing installation: llvmlite 0.39.1
#     Uninstalling llvmlite-0.39.1:
#       Successfully uninstalled llvmlite-0.39.1
#   Attempting uninstall: numba
#     Found existing installation: numba 0.56.4
#     Uninstalling numba-0.56.4:
#       Successfully uninstalled numba-0.56.4
# Successfully installed Levenshtein-0.22.0 huggingface-hub-0.16.4 llvmlite-0.41.0 numba-0.58.0 python-Levenshtein-0.22.0 rapidfuzz-3.3.1 safetensors-0.3.3 shorttext-1.6.0 tokenizers-0.14.0 transformers-4.34.0

# %%
# !python -m spacy download en
# Out:
# 2023-10-05 17:18:16.758243: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-10-05 17:18:17.971940: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# ⚠ As of spaCy v3.0, shortcuts like 'en' are deprecated. Please use the
# full pipeline package name 'en_core_web_sm' instead.
# Collecting en-core-web-sm==3.6.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.6.0/en_core_web_sm-3.6.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 74.7 MB/s eta 0:00:00
# Requirement already satisfied: spacy<3.7.0,>=3.6.0 in /usr/local/lib/python3.10/dist-packages (from en-core-web-sm==3.6.0) (3.6.1)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.0.9)
# Requirement already satisfied: thinc<8.2.0,>=8.1.8 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.12)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.10)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.9.0)
# Requirement already satisfied: pathy>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.10.2)
# Requirement already satisfied: smart-open<7.0.0,>=5.2.1 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (6.4.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.66.1)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.23.5)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.31.0)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (1.10.13)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (67.7.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (23.2)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from pydantic!=1.8,!=1.8.1,<3.0.0,>=1.7.4->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.13.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2023.7.22)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /usr/local/lib/python3.10/dist-packages (from thinc<8.2.0,>=8.1.8->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (0.1.3)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /usr/local/lib/python3.10/dist-packages (from typer<0.10.0,>=0.3.0->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (8.1.7)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->spacy<3.7.0,>=3.6.0->en-core-web-sm==3.6.0) (2.1.3)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/My Drive/ColabData
# %cd /content/drive/My Drive/ColabData
# Out:
# /content/drive/My Drive/ColabData

# %%
from nltk.corpus import PlaintextCorpusReader
corpus_root = 'HealthNews' # Folder Name
filelists = PlaintextCorpusReader(corpus_root, '.*',encoding='latin-1')  # wildcard is read all files in the folder
filelists.fileids()  # Get the filenames
# Out:
# ['.DS_Store',
#  'Dentistry00500.txt',
#  'Dentistry00501.txt',
#  'Dentistry00502.txt',
#  'Dentistry00503.txt',
#  'Dentistry00504.txt',
#  'Dentistry00505.txt',
#  'Dentistry00506.txt',
#  'Dentistry00507.txt',
#  'Dentistry00508.txt',
#  'Dentistry00509.txt',
#  'Dentistry00510.txt',
#  'Dentistry00511.txt',
#  'Dentistry00512.txt',
#  'Dentistry00513.txt',
#  'Dentistry00514.txt',
#  'Dentistry00515.txt',
#  'Dentistry00516.txt',
#  'Dentistry00517.txt',
#  'Dentistry00518.txt',
#  'Dentistry00519.txt',
#  'Dentistry00520.txt',
#  'Dentistry00521.txt',
#  'Dentistry00522.txt',
#  'Dentistry00523.txt',
#  'Dentistry00524.txt',
#  'Dentistry00525.txt',
#  'Dentistry00526.txt',
#  'Dentistry00527.txt',
#  'Dentistry00528.txt',
#  'Dentistry00529.txt',
#  'Dentistry00530.txt',
#  'Dentistry00531.txt',
#  'Dentistry00532.txt',
#  'Dentistry00533.txt',
#  'Dentistry00534.txt',
#  'Dentistry00535.txt',
#  'Dentistry00536.txt',
#  'Dentistry00537.txt',
#  'Dentistry00538.txt',
#  'Dentistry00539.txt',
#  'Dentistry00540.txt',
#  'Dentistry00541.txt',
#  'Dentistry00542.txt',
#  'Dentistry00543.txt',
#  'Dentistry00544.txt',
#  'Dentistry00545.txt',
#  'Dentistry00546.txt',
#  'Dentistry00547.txt',
#  'Dentistry00548.txt',
#  'Dentistry00549.txt',
#  'Dentistry00550.txt',
#  'Dentistry00551.txt',
#  'Dentistry00552.txt',
#  'Dentistry00553.txt',
#  'Dentistry00554.txt',
#  'Dentistry00555.txt',
#  'Dentistry00556.txt',
#  'Dentistry00557.txt',
#  'Dentistry00558.txt',
#  'Dentistry00559.txt',
#  'Depression00500.txt',
#  'Depression00501.txt',
#  'Depression00502.txt',
#  'Depression00503.txt',
#  'Depression00504.txt',
#  'Depression00505.txt',
#  'Depression00506.txt',
#  'Depression00507.txt',
#  'Depression00508.txt',
#  'Depression00509.txt',
#  'Depression00510.txt',
#  'Depression00511.txt',
#  'Depression00512.txt',
#  'Depression00513.txt',
#  'Depression00514.txt',
#  'Depression00515.txt',
#  'Depression00516.txt',
#  'Depression00517.txt',
#  'Depression00518.txt',
#  'Depression00519.txt',
#  'Depression00520.txt',
#  'Depression00521.txt',
#  'Depression00522.txt',
#  'Depression00523.txt',
#  'Depression00524.txt',
#  'Depression00525.txt',
#  'Depression00526.txt',
#  'Depression00527.txt',
#  'Depression00528.txt',
#  'Depression00529.txt',
#  'Depression00530.txt',
#  'Depression00531.txt',
#  'Depression00532.txt',
#  'Depression00533.txt',
#  'Depression00534.txt',
#  'Depression00535.txt',
#  'Depression00536.txt',
#  'Depression00537.txt',
#  'Depression00538.txt',
#  'Depression00539.txt',
#  'Diabetes00500.txt',
#  'Diabetes00501.txt',
#  'Diabetes00502.txt',
#  'Diabetes00503.txt',
#  'Diabetes00504.txt',
#  'Diabetes00505.txt',
#  'Diabetes00506.txt',
#  'Diabetes00507.txt',
#  'Diabetes00508.txt',
#  'Diabetes00509.txt',
#  'Diabetes00510.txt',
#  'Diabetes00511.txt',
#  'Diabetes00512.txt',
#  'Diabetes00513.txt',
#  'Diabetes00514.txt',
#  'Diabetes00515.txt',
#  'Diabetes00516.txt',
#  'Diabetes00517.txt',
#  'Diabetes00518.txt',
#  'Diabetes00519.txt',
#  'Diabetes00520.txt',
#  'Diabetes00521.txt',
#  'Diabetes00522.txt',
#  'Diabetes00523.txt',
#  'Diabetes00524.txt',
#  'Diabetes00525.txt',
#  'Diabetes00526.txt',
#  'Diabetes00527.txt',
#  'Diabetes00528.txt',
#  'Diabetes00529.txt',
#  'Diabetes00530.txt',
#  'Diabetes00531.txt',
#  'Diabetes00532.txt',
#  'Diabetes00533.txt',
#  'Diabetes00534.txt',
#  'Diabetes00535.txt',
#  'Diabetes00536.txt',
#  'Diabetes00537.txt',
#  'Diabetes00538.txt',
#  'Diabetes00539.txt',
#  'Diabetes00540.txt',
#  'Diabetes00541.txt',
#  'Diabetes00542.txt',
#  'Diabetes00543.txt',
#  'Diabetes00544.txt',
#  'Diabetes00545.txt',
#  'Diabetes00546.txt',
#  'Diabetes00547.txt',
#  'Diabetes00548.txt',
#  'Diabetes00549.txt',
#  'Diabetes00550.txt',
#  'Diabetes00551.txt',
#  'Diabetes00552.txt',
#  'Diabetes00553.txt',
#  'Diabetes00554.txt',
#  'Diabetes00555.txt',
#  'Diabetes00556.txt',
#  'Diabetes00557.txt',
#  'Diabetes00558.txt',
#  'Diabetes00559.txt',
#  'Diabetes00560.txt',
#  'Diabetes00561.txt',
#  'Diabetes00562.txt',
#  'Diabetes00563.txt',
#  'Diabetes00564.txt',
#  'Diabetes00565.txt',
#  'Diabetes00566.txt',
#  'Diabetes00567.txt',
#  'Diabetes00568.txt',
#  'Diabetes00569.txt',
#  'Diabetes00570.txt',
#  'Diabetes00571.txt',
#  'Diabetes00572.txt',
#  'Diabetes00573.txt',
#  'Diabetes00574.txt',
#  'Diabetes00575.txt',
#  'Diabetes00576.txt',
#  'Diabetes00577.txt',
#  'Diabetes00578.txt',
#  'Diabetes00579.txt',
#  'Diabetes00580.txt',
#  'Diabetes00581.txt',
#  'Diabetes00582.txt',
#  'Diabetes00583.txt',
#  'Diabetes00584.txt',
#  'Diabetes00585.txt',
#  'Diabetes00586.txt',
#  'Diabetes00587.txt',
#  'Diabetes00588.txt',
#  'Diabetes00589.txt',
#  'Diabetes00590.txt',
#  'Diabetes00591.txt',
#  'Diabetes00592.txt',
#  'Diabetes00593.txt',
#  'Diabetes00594.txt',
#  'Diabetes00595.txt',
#  'Diabetes00596.txt',
#  'Diabetes00597.txt',
#  'Diabetes00598.txt',
#  'Diabetes00599.txt']

# %%
#create a list of news articles
news = []
for fileid in filelists.fileids():
    news.append(filelists.raw(fileid))

# %%
news[25]
# Out:
# 'New type of cell movement discovered\n <p>For decades, researchers have used petri dishes to study cell movement. These classic tissue culture tools, however, only permit two-dimensional movement, very different from the three-dimensional movements that cells make in a human body.</p><div class="photobox_right" style=\'max-width:349px;\' ><img src="http://www.medicalnewstoday.com/images/articles/281/281729/cell-moving-through-a-3-d-matrix.jpg" alt="Cell Moving through a 3-D Matrix"><br><em>Penn and NIH researchers measured the internal pressure of individual fibroblast cells (in orange) moving through a three-dimensional matrix (in blue). They found that, in this environment, the cells\' nuclei operate like an engine\'s piston to push the cell forward.<br>Credit: University of Pennsylvania/NIDCR</em></div><p>In a new study from the University of Pennsylvania and National Institute of Dental and Craniofacial Research, scientists used an innovative technique to study how cells move in a three-dimensional matrix, similar to the structure of certain tissues, such as the skin. They discovered an entirely new type of cell movement whereby the nucleus helps propel cells through the matrix like a piston in an engine, generating pressure that thrusts the cell\'s plasma membrane forward.</p><p>"Our work elucidated a highly intriguing question: how cells move when they are in the complex and physiologically relevant environment of a 3-D extracellular matrix," said Hyun (Michel) Koo, a professor in the Department of Orthodontics at Penn\'s School of Dental Medicine. "We discovered that the nucleus can act as a piston that physically compartmentalizes the cell cytoplasm and increases the hydrostatic pressure driving the cell motility within a 3-D matrix."</p><p>Koo worked with lead author Ryan Petrie and senior author Kenneth Yamada, both of the National Institutes of Health\'s NIDCR, on the study, which is published in<em> Science.</em></p><p>"We think it\'s a very important normal physiological mechanism of cell movement that has not been characterized previously," Petrie said.</p><p>The team studied fibroblasts, the most common type of cell found in connective tissue. Fibroblasts themselves produce proteins including collagen and fibronectin that connect in a complex matrix that is found in the skin, the intestines and other tissues in the body.</p><p>The researchers used this fibroblast-created matrix to test how cells migrate through a three-dimensional structure. The matrix is crosslinked, meaning its fibers are resistant to bending and flexing as the cells move through.</p><p>Studies of fibroblasts on two-dimensional surfaces indicated that the most typical form of movement involved protrusions called lamellipodia, created by the polymerization of the protein actin into fibers that push the cell membrane forward. In 2012, however, Petrie and Yamada showed that when fibroblasts migrate they can switch to a different movement strategy when placed in a three-dimensional matrix, using blunt protrusions called lobopodia.</p><p>What the researchers did not know was how these lobopodia were formed. Suspecting they might be generated from increased intracellular pressure, the team used sophisticated microelectrodes to measure the hydrostatic pressure of the fluid inside the cell. They found that the pressure was significantly higher in cells moving in a three-dimensional extracellular matrix compared to cells moving along a two-dimensional surface or in a three-dimensional matrix that wasn\'t cross linked like the fibroblast-derived matrix.</p><p>To drill down further and see how the pressure was distributed within the cell moving in a three-dimensional matrix, they measured pressure from in front of and behind the nucleus. Cells moving using lobopodia have elevated pressure in front of the nucleus but not behind it, generating energy to propel the cell forward. Using live-cell confocal microscopy, they observed that the nucleus could be p ...

# %%
# import the shorttext library for text preprocessing
#standard_text_preprocessor_1 under shorttext.utils provides a standar way of text preprocessing, including the following steps:

   #1. removing special characters,
   #2. removing numerals,
   #3. converting all alphabets to lower cases,
   #4. removing stop words, and
   #5. stemming the words (using Porter stemmer).

from shorttext.utils import standard_text_preprocessor_1, DocumentTermMatrix
preprocessor = standard_text_preprocessor_1()
corpus = [preprocessor(article).split(' ') for article in news]

# %%
corpus[25]
# Out:
# ['new',
#  'type',
#  'cell',
#  'movement',
#  'discovered\n',
#  'pfor',
#  'decad',
#  'research',
#  'us',
#  'petri',
#  'dish',
#  'studi',
#  'cell',
#  'movement',
#  'classic',
#  'tissu',
#  'cultur',
#  'tool',
#  'howev',
#  'permit',
#  'twodimension',
#  'movement',
#  'differ',
#  'threedimension',
#  'movement',
#  'cell',
#  'make',
#  'human',
#  'bodypdiv',
#  'classphotobox_right',
#  'stylemaxwidthpx',
#  'img',
#  'srchttpwwwmedicalnewstodaycomimagesarticlescellmovingthroughadmatrixjpg',
#  'altcel',
#  'move',
#  'matrixbrempenn',
#  'nih',
#  'research',
#  'measur',
#  'intern',
#  'pressur',
#  'individu',
#  'fibroblast',
#  'cell',
#  'orang',
#  'move',
#  'threedimension',
#  'matrix',
#  'blue',
#  'found',
#  'environ',
#  'cell',
#  'nuclei',
#  'oper',
#  'like',
#  'engin',
#  'piston',
#  'push',
#  'cell',
#  'forwardbrcredit',
#  'univers',
#  'pennsylvanianidcremdivpin',
#  'new',
#  'studi',
#  'univers',
#  'pennsylvania',
#  'nation',
#  'institut',
#  'dental',
#  'craniofaci',
#  'research',
#  'scientist',
#  'us',
#  'innov',
#  'techniqu',
#  'studi',
#  'cell',
#  'move',
#  'threedimension',
#  'matrix',
#  'similar',
#  'structur',
#  'certain',
#  'tissu',
#  'skin',
#  'discov',
#  'entir',
#  'new',
#  'type',
#  'cell',
#  'movement',
#  'wherebi',
#  'nucleu',
#  'help',
#  'propel',
#  'cell',
#  'matrix',
#  'like',
#  'piston',
#  'engin',
#  'gener',
#  'pressur',
#  'thrust',
#  'cell',
#  'plasma',
#  'membran',
#  'forwardppour',
#  'work',
#  'elucid',
#  'highli',
#  'intrigu',
#  'question',
#  'cell',
#  'move',
#  'complex',
#  'physiolog',
#  'relev',
#  'environ',
#  'extracellular',
#  'matrix',
#  'said',
#  'hyun',
#  'michel',
#  'koo',
#  'professor',
#  'depart',
#  'orthodont',
#  'penn',
#  'school',
#  'dental',
#  'medicin',
#  'discov',
#  'nucleu',
#  'act',
#  'piston',
#  'physic',
#  'compartment',
#  'cell',
#  'cytoplasm',
#  'increas',
#  'hydrostat',
#  'pressur',
#  'drive',
#  'cell',
#  'motil',
#  'within',
#  'matrixppkoo',
#  'work',
#  'lead',
#  'author',
#  'ryan',
#  'petri',
#  'senior',
#  'author',
#  'kenneth',
#  'yamada',
#  'nation',
#  'institut',
#  'health',
#  'nidcr',
#  'studi',
#  'publish',
#  'inem',
#  'scienceemppw',
#  'think',
#  'import',
#  'normal',
#  'physiolog',
#  'mechan',
#  'cell',
#  'movement',
#  'character',
#  'previous',
#  'petri',
#  'saidppth',
#  'team',
#  'studi',
#  'fibroblast',
#  'common',
#  'type',
#  'cell',
#  'found',
#  'connect',
#  'tissu',
#  'fibroblast',
#  'produc',
#  'protein',
#  'includ',
#  'collagen',
#  'fibronectin',
#  'connect',
#  'complex',
#  'matrix',
#  'found',
#  'skin',
#  'intestin',
#  'tissu',
#  'bodyppth',
#  'research',
#  'us',
#  'fibroblastcr',
#  'matrix',
#  'test',
#  'cell',
#  'migrat',
#  'threedimension',
#  'structur',
#  'matrix',
#  'crosslink',
#  'mean',
#  'fiber',
#  'resist',
#  'bend',
#  'flex',
#  'cell',
#  'move',
#  'throughppstudi',
#  'fibroblast',
#  'twodimension',
#  'surfac',
#  'indic',
#  'typic',
#  'form',
#  'movement',
#  'involv',
#  'protrus',
#  'call',
#  'lamellipodia',
#  'creat',
#  'polymer',
#  'protein',
#  'actin',
#  'fiber',
#  'push',
#  'cell',
#  'membran',
#  'forward',
#  '',
#  'howev',
#  'petri',
#  'yamada',
#  'show',
#  'fibroblast',
#  'migrat',
#  'switch',
#  'differ',
#  'movement',
#  'strategi',
#  'place',
#  'threedimension',
#  'matrix',
#  'us',
#  'blunt',
#  'protrus',
#  'call',
#  'lobopodiappwhat',
#  'research',
#  'know',
#  'lobopodia',
#  'form',
#  'suspect',
#  'might',
#  'gener',
#  'increas',
#  'intracellular',
#  'pressur',
#  'team',
#  'us',
#  'sophist',
#  'microelectrod',
#  'measur',
#  'hydrostat',
#  'pressur',
#  'fluid',
#  'insid',
#  'cell',
#  'found',
#  'pressur',
#  'significantli',
#  'higher',
#  'cell',
#  'move',
#  'threedimension',
#  'extracellular',
#  'matrix',
#  'compar',
#  'cell',
#  'move',
#  'along',
#  'twodimension',
#  'surfac',
#  'threedimension',
#  'matrix',
#  'wasnt',
#  'cross',
#  'link',
#  'like',
#  'fibroblastderiv',
#  'matrixppto',
#  'drill',
#  'see',
#  'pressur',
#  'distribut',
#  'within',
#  'cell',
#  'move',
#  'threedimension',
#  'matrix',
#  'measur',
#  'pressur',
#  'front',
#  'behind',
#  'nucleu',
#  'cell',
#  'move',
#  'us',
#  'lobopodia',
#  'elev',
#  'pressur',
#  'front',
#  'nucleu',
#  'behind',
#  'gener',
#  'energi',
#  'propel',
#  'cell',
#  'forward',
#  'us',
#  'livecel',
#  'confoc',
#  'microscopi',
#  'observ',
#  'nucleu',
#  'could',
#  'pull',
#  'forward',
#  'awai',
#  'rear',
#  'cell',
#  'nucleu',
#  'divid',
#  'cell',
#  'lowpressur',
#  'highpressur',
#  'compartmentsppwhen',
#  'cell',
#  'matrix',
#  'nucleu',
#  'tend',
#  'back',
#  'cell',
#  'cell',
#  'bodi',
#  'tubular',
#  'shape',
#  'petri',
#  'said',
#  'realli',
#  'look',
#  'like',
#  'pistonppthei',
#  'found',
#  'nucleu',
#  'actual',
#  'pull',
#  'forward',
#  'actin',
#  'filament',
#  'connect',
#  'nucleu',
#  'front',
#  'cell',
#  'movement',
#  'pressur',
#  'cell',
#  'scientist',
#  'abl',
#  'identifi',
#  'protein',
#  'compon',
#  'respons',
#  'move',
#  'nuclear',
#  'piston',
#  'includ',
#  'actomyosin',
#  'vimentin',
#  'nesprinppth',
#  'pressur',
#  'push',
#  'plasma',
#  'membran',
#  'petri',
#  'saidppbecaus',
#  'happen',
#  'cell',
#  'move',
#  'threedimension',
#  'cellcreat',
#  'matrix',
#  'cell',
#  'move',
#  'substrat',
#  'research',
#  'note',
#  'cell',
#  'must',
#  'sens',
#  'physic',
#  'environ',
#  'determin',
#  'type',
#  'movement',
#  'useppthi',
#  'type',
#  'cell',
#  'migrat',
#  'might',
#  'common',
#  'tissu',
#  'bodi',
#  'research',
#  'note',
#  'took',
#  'chondrocyt',
#  'knee',
#  'cartilag',
#  'myofibroblast',
#  'intestin',
#  'tissu',
#  'place',
#  'matrix',
#  'cell',
#  'us',
#  'type',
#  'lobopodiadriven',
#  'motionppth',
#  'discoveri',
#  'could',
#  'implic',
#  'understand',
#  'diseas',
#  'cancer',
#  'well',
#  'cancer',
#  'cell',
#  'tend',
#  'move',
#  'distinct',
#  'wai',
#  'normal',
#  'cellsppit',
#  'might',
#  'give',
#  'u',
#  'leverag',
#  'find',
#  'uniqu',
#  'cancer',
#  'cell',
#  'target',
#  'therapeut',
#  'affect',
#  'normal',
#  'cell',
#  'petri',
#  'saidppimportantli',
#  'find',
#  'could',
#  'broader',
#  'relev',
#  'biolog',
#  'system',
#  'live',
#  'cell',
#  'enmesh',
#  'within',
#  'surround',
#  'extracellular',
#  'matrix',
#  'biofilm',
#  'associ',
#  'mani',
#  'human',
#  'infecti',
#  'diseasesppthi',
#  'work',
#  'illustr',
#  'physic',
#  'structur',
#  'matrix',
#  'influenc',
#  'cellular',
#  'properti',
#  'govern',
#  'biolog',
#  'function',
#  'koo',
#  'said',
#  'appli',
#  'fascin',
#  'principl',
#  'understand',
#  'biofilm',
#  'matrix',
#  'modul',
#  'bacteri',
#  'virul',
#  'caus',
#  'oral',
#  'diseas',
#  'dental',
#  'cariesp',
#  '\nfor',
#  'decad',
#  'research',
#  'us',
#  'petri',
#  'dish',
#  'studi',
#  'cell',
#  'movement',
#  'classic',
#  'tissu',
#  'cultur',
#  'tool',
#  'howev',
#  'permit',
#  'twodimension',
#  'movement',
#  'differ',
#  'the\n']

# %%
#convert the corpus of news to a document term matrix (dtm), where each row represents a document, each column represents the number of occurence for a word

dtm = DocumentTermMatrix(corpus, docids = filelists.fileids())

# %%
#check number of occurence of the word "associ" in each document
dtm.get_token_occurences('associ')
# Out:
# {'Dentistry00500.txt': 5.0,
#  'Dentistry00502.txt': 2.0,
#  'Dentistry00503.txt': 1.0,
#  'Dentistry00505.txt': 1.0,
#  'Dentistry00506.txt': 1.0,
#  'Dentistry00512.txt': 2.0,
#  'Dentistry00514.txt': 8.0,
#  'Dentistry00515.txt': 4.0,
#  'Dentistry00516.txt': 1.0,
#  'Dentistry00518.txt': 2.0,
#  'Dentistry00521.txt': 1.0,
#  'Dentistry00523.txt': 7.0,
#  'Dentistry00524.txt': 1.0,
#  'Dentistry00525.txt': 2.0,
#  'Dentistry00526.txt': 1.0,
#  'Dentistry00528.txt': 3.0,
#  'Dentistry00529.txt': 1.0,
#  'Dentistry00530.txt': 8.0,
#  'Dentistry00533.txt': 2.0,
#  'Dentistry00534.txt': 1.0,
#  'Dentistry00535.txt': 1.0,
#  'Dentistry00536.txt': 2.0,
#  'Dentistry00537.txt': 3.0,
#  'Dentistry00538.txt': 2.0,
#  'Dentistry00541.txt': 3.0,
#  'Dentistry00542.txt': 1.0,
#  'Dentistry00544.txt': 1.0,
#  'Dentistry00548.txt': 4.0,
#  'Dentistry00549.txt': 2.0,
#  'Dentistry00550.txt': 2.0,
#  'Dentistry00552.txt': 3.0,
#  'Dentistry00553.txt': 2.0,
#  'Dentistry00554.txt': 1.0,
#  'Dentistry00555.txt': 1.0,
#  'Dentistry00556.txt': 3.0,
#  'Dentistry00557.txt': 2.0,
#  'Dentistry00558.txt': 2.0,
#  'Dentistry00559.txt': 1.0,
#  'Depression00500.txt': 1.0,
#  'Depression00501.txt': 1.0,
#  'Depression00505.txt': 2.0,
#  'Depression00506.txt': 2.0,
#  'Depression00509.txt': 1.0,
#  'Depression00514.txt': 1.0,
#  'Depression00515.txt': 1.0,
#  'Depression00518.txt': 3.0,
#  'Depression00520.txt': 2.0,
#  'Depression00525.txt': 2.0,
#  'Depression00527.txt': 6.0,
#  'Depression00528.txt': 7.0,
#  'Depression00529.txt': 1.0,
#  'Depression00531.txt': 2.0,
#  'Depression00532.txt': 2.0,
#  'Depression00533.txt': 5.0,
#  'Depression00534.txt': 1.0,
#  'Depression00535.txt': 3.0,
#  'Depression00536.txt': 2.0,
#  'Depression00537.txt': 2.0,
#  'Depression00538.txt': 2.0,
#  'Depression00539.txt': 4.0,
#  'Diabetes00500.txt': 1.0,
#  'Diabetes00502.txt': 1.0,
#  'Diabetes00503.txt': 1.0,
#  'Diabetes00504.txt': 3.0,
#  'Diabetes00506.txt': 1.0,
#  'Diabetes00508.txt': 1.0,
#  'Diabetes00509.txt': 2.0,
#  'Diabetes00510.txt': 4.0,
#  'Diabetes00513.txt': 4.0,
#  'Diabetes00515.txt': 4.0,
#  'Diabetes00518.txt': 1.0,
#  'Diabetes00520.txt': 1.0,
#  'Diabetes00522.txt': 1.0,
#  'Diabetes00523.txt': 2.0,
#  'Diabetes00528.txt': 3.0,
#  'Diabetes00530.txt': 1.0,
#  'Diabetes00533.txt': 1.0,
#  'Diabetes00534.txt': 2.0,
#  'Diabetes00535.txt': 9.0,
#  'Diabetes00537.txt': 1.0,
#  'Diabetes00538.txt': 1.0,
#  'Diabetes00540.txt': 1.0,
#  'Diabetes00541.txt': 4.0,
#  'Diabetes00543.txt': 1.0,
#  'Diabetes00544.txt': 1.0,
#  'Diabetes00545.txt': 4.0,
#  'Diabetes00547.txt': 2.0,
#  'Diabetes00549.txt': 2.0,
#  'Diabetes00550.txt': 2.0,
#  'Diabetes00551.txt': 1.0,
#  'Diabetes00553.txt': 1.0,
#  'Diabetes00554.txt': 3.0,
#  'Diabetes00557.txt': 2.0,
#  'Diabetes00558.txt': 2.0,
#  'Diabetes00559.txt': 3.0,
#  'Diabetes00560.txt': 2.0,
#  'Diabetes00563.txt': 2.0,
#  'Diabetes00565.txt': 1.0,
#  'Diabetes00567.txt': 1.0,
#  'Diabetes00570.txt': 1.0,
#  'Diabetes00571.txt': 3.0,
#  'Diabetes00573.txt': 2.0,
#  'Diabetes00575.txt': 2.0,
#  'Diabetes00576.txt': 1.0,
#  'Diabetes00577.txt': 1.0,
#  'Diabetes00578.txt': 5.0,
#  'Diabetes00579.txt': 1.0,
#  'Diabetes00580.txt': 2.0,
#  'Diabetes00581.txt': 1.0,
#  'Diabetes00582.txt': 8.0,
#  'Diabetes00583.txt': 3.0,
#  'Diabetes00584.txt': 2.0,
#  'Diabetes00585.txt': 1.0,
#  'Diabetes00587.txt': 1.0,
#  'Diabetes00589.txt': 2.0,
#  'Diabetes00591.txt': 3.0,
#  'Diabetes00592.txt': 2.0,
#  'Diabetes00593.txt': 1.0,
#  'Diabetes00594.txt': 2.0,
#  'Diabetes00595.txt': 3.0,
#  'Diabetes00596.txt': 1.0,
#  'Diabetes00597.txt': 2.0}

# %%
type(dtm.get_token_occurences('associ'))
# Out:
# dict

# %%
# define a function to calculate entropy given a distribution
import numpy as np
import math

def entropy(p):
    if sum(p) == 0:
        return 0

    p = p/sum(p)

    p = p[ p > 0 ]

    H = -sum(p*np.log2(p))

    return H

# %%
entropy(np.array( [12,45]))
# Out:
# 0.7424875695421236

# %%
entropy( np.array( [100,60,40]))
# Out:
# 1.4854752972273344

# %%
dtm.get_token_occurences('associ').keys()
# Out:
# dict_keys(['Dentistry00500.txt', 'Dentistry00502.txt', 'Dentistry00503.txt', 'Dentistry00505.txt', 'Dentistry00506.txt', 'Dentistry00512.txt', 'Dentistry00514.txt', 'Dentistry00515.txt', 'Dentistry00516.txt', 'Dentistry00518.txt', 'Dentistry00521.txt', 'Dentistry00523.txt', 'Dentistry00524.txt', 'Dentistry00525.txt', 'Dentistry00526.txt', 'Dentistry00528.txt', 'Dentistry00529.txt', 'Dentistry00530.txt', 'Dentistry00533.txt', 'Dentistry00534.txt', 'Dentistry00535.txt', 'Dentistry00536.txt', 'Dentistry00537.txt', 'Dentistry00538.txt', 'Dentistry00541.txt', 'Dentistry00542.txt', 'Dentistry00544.txt', 'Dentistry00548.txt', 'Dentistry00549.txt', 'Dentistry00550.txt', 'Dentistry00552.txt', 'Dentistry00553.txt', 'Dentistry00554.txt', 'Dentistry00555.txt', 'Dentistry00556.txt', 'Dentistry00557.txt', 'Dentistry00558.txt', 'Dentistry00559.txt', 'Depression00500.txt', 'Depression00501.txt', 'Depression00505.txt', 'Depression00506.txt', 'Depression00509.txt', 'Depression00514.txt', 'Depression00515.txt', 'Depression00518.txt', 'Depression00520.txt', 'Depression00525.txt', 'Depression00527.txt', 'Depression00528.txt', 'Depression00529.txt', 'Depression00531.txt', 'Depression00532.txt', 'Depression00533.txt', 'Depression00534.txt', 'Depression00535.txt', 'Depression00536.txt', 'Depression00537.txt', 'Depression00538.txt', 'Depression00539.txt', 'Diabetes00500.txt', 'Diabetes00502.txt', 'Diabetes00503.txt', 'Diabetes00504.txt', 'Diabetes00506.txt', 'Diabetes00508.txt', 'Diabetes00509.txt', 'Diabetes00510.txt', 'Diabetes00513.txt', 'Diabetes00515.txt', 'Diabetes00518.txt', 'Diabetes00520.txt', 'Diabetes00522.txt', 'Diabetes00523.txt', 'Diabetes00528.txt', 'Diabetes00530.txt', 'Diabetes00533.txt', 'Diabetes00534.txt', 'Diabetes00535.txt', 'Diabetes00537.txt', 'Diabetes00538.txt', 'Diabetes00540.txt', 'Diabetes00541.txt', 'Diabetes00543.txt', 'Diabetes00544.txt', 'Diabetes00545.txt', 'Diabetes00547.txt', 'Diabetes00549.txt', 'Diabetes00550.txt', 'Diabetes00551.txt', 'Diabetes00553.txt', 'Diabetes00554.txt', 'Diabetes00557.txt', 'Diabetes00558.txt', 'Diabetes00559.txt', 'Diabetes00560.txt', 'Diabetes00563.txt', 'Diabetes00565.txt', 'Diabetes00567.txt', 'Diabetes00570.txt', 'Diabetes00571.txt', 'Diabetes00573.txt', 'Diabetes00575.txt', 'Diabetes00576.txt', 'Diabetes00577.txt', 'Diabetes00578.txt', 'Diabetes00579.txt', 'Diabetes00580.txt', 'Diabetes00581.txt', 'Diabetes00582.txt', 'Diabetes00583.txt', 'Diabetes00584.txt', 'Diabetes00585.txt', 'Diabetes00587.txt', 'Diabetes00589.txt', 'Diabetes00591.txt', 'Diabetes00592.txt', 'Diabetes00593.txt', 'Diabetes00594.txt', 'Diabetes00595.txt', 'Diabetes00596.txt', 'Diabetes00597.txt'])

# %%
#convert the documents that contain the word "associ" from dictionary keys to a list
associ_docs = list(dtm.get_token_occurences('associ').keys())
associ_docs
# Out:
# ['Dentistry00500.txt',
#  'Dentistry00502.txt',
#  'Dentistry00503.txt',
#  'Dentistry00505.txt',
#  'Dentistry00506.txt',
#  'Dentistry00512.txt',
#  'Dentistry00514.txt',
#  'Dentistry00515.txt',
#  'Dentistry00516.txt',
#  'Dentistry00518.txt',
#  'Dentistry00521.txt',
#  'Dentistry00523.txt',
#  'Dentistry00524.txt',
#  'Dentistry00525.txt',
#  'Dentistry00526.txt',
#  'Dentistry00528.txt',
#  'Dentistry00529.txt',
#  'Dentistry00530.txt',
#  'Dentistry00533.txt',
#  'Dentistry00534.txt',
#  'Dentistry00535.txt',
#  'Dentistry00536.txt',
#  'Dentistry00537.txt',
#  'Dentistry00538.txt',
#  'Dentistry00541.txt',
#  'Dentistry00542.txt',
#  'Dentistry00544.txt',
#  'Dentistry00548.txt',
#  'Dentistry00549.txt',
#  'Dentistry00550.txt',
#  'Dentistry00552.txt',
#  'Dentistry00553.txt',
#  'Dentistry00554.txt',
#  'Dentistry00555.txt',
#  'Dentistry00556.txt',
#  'Dentistry00557.txt',
#  'Dentistry00558.txt',
#  'Dentistry00559.txt',
#  'Depression00500.txt',
#  'Depression00501.txt',
#  'Depression00505.txt',
#  'Depression00506.txt',
#  'Depression00509.txt',
#  'Depression00514.txt',
#  'Depression00515.txt',
#  'Depression00518.txt',
#  'Depression00520.txt',
#  'Depression00525.txt',
#  'Depression00527.txt',
#  'Depression00528.txt',
#  'Depression00529.txt',
#  'Depression00531.txt',
#  'Depression00532.txt',
#  'Depression00533.txt',
#  'Depression00534.txt',
#  'Depression00535.txt',
#  'Depression00536.txt',
#  'Depression00537.txt',
#  'Depression00538.txt',
#  'Depression00539.txt',
#  'Diabetes00500.txt',
#  'Diabetes00502.txt',
#  'Diabetes00503.txt',
#  'Diabetes00504.txt',
#  'Diabetes00506.txt',
#  'Diabetes00508.txt',
#  'Diabetes00509.txt',
#  'Diabetes00510.txt',
#  'Diabetes00513.txt',
#  'Diabetes00515.txt',
#  'Diabetes00518.txt',
#  'Diabetes00520.txt',
#  'Diabetes00522.txt',
#  'Diabetes00523.txt',
#  'Diabetes00528.txt',
#  'Diabetes00530.txt',
#  'Diabetes00533.txt',
#  'Diabetes00534.txt',
#  'Diabetes00535.txt',
#  'Diabetes00537.txt',
#  'Diabetes00538.txt',
#  'Diabetes00540.txt',
#  'Diabetes00541.txt',
#  'Diabetes00543.txt',
#  'Diabetes00544.txt',
#  'Diabetes00545.txt',
#  'Diabetes00547.txt',
#  'Diabetes00549.txt',
#  'Diabetes00550.txt',
#  'Diabetes00551.txt',
#  'Diabetes00553.txt',
#  'Diabetes00554.txt',
#  'Diabetes00557.txt',
#  'Diabetes00558.txt',
#  'Diabetes00559.txt',
#  'Diabetes00560.txt',
#  'Diabetes00563.txt',
#  'Diabetes00565.txt',
#  'Diabetes00567.txt',
#  'Diabetes00570.txt',
#  'Diabetes00571.txt',
#  'Diabetes00573.txt',
#  'Diabetes00575.txt',
#  'Diabetes00576.txt',
#  'Diabetes00577.txt',
#  'Diabetes00578.txt',
#  'Diabetes00579.txt',
#  'Diabetes00580.txt',
#  'Diabetes00581.txt',
#  'Diabetes00582.txt',
#  'Diabetes00583.txt',
#  'Diabetes00584.txt',
#  'Diabetes00585.txt',
#  'Diabetes00587.txt',
#  'Diabetes00589.txt',
#  'Diabetes00591.txt',
#  'Diabetes00592.txt',
#  'Diabetes00593.txt',
#  'Diabetes00594.txt',
#  'Diabetes00595.txt',
#  'Diabetes00596.txt',
#  'Diabetes00597.txt']

# %%
#print the number of "Dentistry" documents that contain the word "associ"
sub = 'Dentistry'
count_dentistry = 0
for item in associ_docs:
    if sub in item:
        count_dentistry += 1
print(count_dentistry)
# Out:
# 38

# %%
#print the number of "Depression" documents that contain the word "associ"
sub = 'Depression'
count_depression = 0
for item in associ_docs:
    if sub in item:
        count_depression += 1
print(count_depression)
# Out:
# 22

# %%
#print the number of "Diabetes" documents that contain the word "associ"
sub = 'Diabetes'
count_diabetes = 0
for item in associ_docs:
    if sub in item:
        count_diabetes += 1
print(count_diabetes)
# Out:
# 62

# %%
#this is an important step
#make an array, rows represent "Dentistry", "Depression", and "Diabetes" respectively. Columns represent the number of documents that contains the word "associ" and the number of documents that do NOT contain the word "associ"
array = np.reshape((count_dentistry,60-count_dentistry,count_depression,40-count_depression,count_diabetes,100-count_diabetes ),(3,2))

# %%
array
# Out:
# array([[38, 22],
#        [22, 18],
#        [62, 38]])

# %%
#calculate the column sum of the array
np.sum(array, axis = 0)
# Out:
# array([122,  78])

# %%
#calculate the entroy of the word "associ"
entropy(np.array( [122,78]))
# Out:
# 0.9647995485050872

# %%
#calculate the row sum of the array
np.sum(array, axis = 1)
# Out:
# array([ 60,  40, 100])

# %%
#calculate the entropy of the document class (Dentistry, Depression, and Diabetes)
entropy_class = entropy(np.sum(array, axis = 1))

# %%
entropy_class
# Out:
# 1.4854752972273344

# %%
#calculate the column probabilities
column_probs = np.sum(array, axis = 0)/200

# %%
column_probs
# Out:
# array([0.61, 0.39])

# %%
#calculate the column entropies
column_entropy = np.apply_along_axis(entropy, 0, array)

# %%
column_entropy
# Out:
# array([1.46607412, 1.50864079])

# %%
column_probs*column_entropy
# Out:
# array([0.89430521, 0.58836991])

# %%
conditional_entropy = sum(column_probs*column_entropy)

# %%
conditional_entropy
# Out:
# 1.4826751237111302

# %%
#calculate the mutual information between the word "associ" and the document class (Dentistry, Depression, and Diabetes)
MI_associ = entropy_class - conditional_entropy

# %%
MI_associ
# Out:
# 0.0028001735162042074

# %%
# the approach above used entropy reduction for the mutual information instead of joint probability
